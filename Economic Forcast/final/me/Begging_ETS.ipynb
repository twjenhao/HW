    343.19,
    340.97,
    341.20,
    342.76,
    343.96,
    344.82,
    345.82,
    347.24,
    348.09,
    348.66,
    347.90,
    346.27,
    344.21,
    342.88,
    342.58,
    343.99,
    345.31,
    345.98,
    346.72,
    347.63,
    349.24,
    349.83,
    349.10,
    347.52,
    345.43,
    344.48,
    343.89,
    345.29,
    346.54,
    347.66,
    348.07,
    349.12,
    350.55,
    351.34,
    350.80,
    349.10,
    347.54,
    346.20,
    346.20,
    347.44,
    348.67,
]
co2 = pd.Series(
    co2, index=pd.date_range("1-1-1959", periods=len(co2), freq="M"), name="CO2"
)

# %%
len(co2)
# Out:
# 348

# %%
co2.plot()
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.seasonal import STL
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from statsmodels.tsa.exponential_smoothing.ets import ETSModel

# %%
# first step: boxcox
co2_bc = boxcox(co2)

# second step: STL
stl = STL(co2,seasonal=13)
res = stl.fit()
trend = res.trend
seasonal = res.seasonal

# %%
# res.plot()
# dir(res)

# %%
# define a function for moving block bootstrap
def mbb(x,l): # l: block size
    n = len(x) # the length of data
    nb = np.int32(n/l)+2
    idx = np.random.randint(n-l,size=nb)
    z = []
    for ii in idx:
        z = z+list(x[ii:ii+l])
    z = z[np.random.randint(l):]
    z = z[:n]
    return(z)

# %%
# third step: moving block bootstrap
l = 24 # block size
B = 10 # number of bootstrapped series

bt_co2 = pd.DataFrame(np.zeros((len(co2),B)),index=co2.index)
for bb in range(B):
    z = mbb(res.resid,l)
    bt_co2.iloc[:,bb]= np.array(z)+trend+seasonal

bt_co2.plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
bt_co2
# Out:
#                      0           1           2           3           4  \
# 1959-01-31  315.943536  315.300646  315.115803  315.284516  315.140149
# 1959-02-28  316.161361  316.213342  316.366262  316.057987  316.181994
# 1959-03-31  316.686202  316.801312  316.698309  317.012266  316.917658
# 1959-04-30  318.009090  318.027379  318.360781  317.899746  317.979010
# 1959-05-31  318.928644  318.754663  318.987446  319.166613  318.861328
# ...                ...         ...         ...         ...         ...
# 1987-08-31  347.199187  347.469261  347.441661  347.660731  347.615706
# 1987-09-30  346.050597  345.912859  345.936773  346.360186  346.372117
# 1987-10-31  346.202221  345.785082  346.013355  345.803092  345.919470
# 1987-11-30  347.823383  346.913544  347.113098  347.006611  347.031778
# 1987-12-31  348.897085  348.540345  348.759535  348.569642  348.274349
#
#                      5           6           7           8           9
# 1959-01-31  315.365598  315.744976  315.466508  315.036978  315.656097
# 1959-02-28  315.581404  315.860169  316.019593  315.947160  316.390225
# 1959-03-31  316.326740  316.705249  316.939898  317.026761  316.478897
# 1959-04-30  317.507171  318.148665  318.080532  317.819257  317.824443
# 1959-05-31  318.552765  318.956531  318.687216  318.758702  318.639445
# ...                ...         ...         ...         ...         ...
# 1987-08-31  347.627123  347.464952  347.377046  347.454598  347.019616
# 1987-09-30  346.206248  346.232446  346.114602  346.114787  345.480793
# 1987-10-31  346.000403  345.939493  346.123564  346.066923  346.050728
# 1987-11-30  347.140402  347.142625  347.324193  347.369852  347.504460
# 1987-12-31  348.095407  348.312923  348.634494  348.706202  348.869024
#
# [348 rows x 10 columns]

# %%
co2.index
# Out:
# DatetimeIndex(['1959-01-31', '1959-02-28', '1959-03-31', '1959-04-30',
#                '1959-05-31', '1959-06-30', '1959-07-31', '1959-08-31',
#                '1959-09-30', '1959-10-31',
#                ...
#                '1987-03-31', '1987-04-30', '1987-05-31', '1987-06-30',
#                '1987-07-31', '1987-08-31', '1987-09-30', '1987-10-31',
#                '1987-11-30', '1987-12-31'],
#               dtype='datetime64[ns]', length=348, freq='M')
